# %% [markdown]
# ## 1. Downloading Videos from YouTube
#
# Here, we download videos from YouTube. In the `group_urls_folder`, create a `.txt` file with the URLs of YouTube videos you want downloaded. Each URL should be on a new line. The saved YouTube videos in WEBM format are saved into the `download_folder`.

# %%
import os
import re
import shutil
import yt_dlp

def download_video(url, output_path):
    ydl_opts = {
        'format': 'bestvideo[ext=webm]+bestaudio[ext=webm]/best',
        'outtmpl': os.path.join(output_path, '%(title)s.%(ext)s'),
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([url])

def sanitize_file_name(name):
    """Remove all characters except a-z, A-Z, and periods from a file name"""
    return re.sub(r'[^a-zA-Z\.]', '', name)

group_urls_folder = "group_urls"
download_folder = "downloaded_videos"

# Iterate through text files in the group_urls folder
for text_file in os.listdir(group_urls_folder):
    if text_file.endswith(".txt"):
        group_name = os.path.splitext(text_file)[0]
        group_download_folder = os.path.join(download_folder, group_name)

        # Create the group download folder if it doesn't exist
        if not os.path.exists(group_download_folder):
            os.makedirs(group_download_folder)

        with open(os.path.join(group_urls_folder, text_file), "r") as f:
            video_urls = f.readlines()

        # Download the videos
        for i, video_url in enumerate(video_urls):
            video_url = video_url.strip()

            # Download the video
            download_video(video_url, group_download_folder)

        # Sanitize the file names
        for file_name in os.listdir(group_download_folder):
            if file_name.endswith(".webm"):
                sanitized_file_name = sanitize_file_name(file_name)
                if sanitized_file_name != file_name:
                    os.rename(os.path.join(group_download_folder, file_name), os.path.join(group_download_folder, sanitized_file_name))
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=cU0JrSAyy7o
# [youtube] cU0JrSAyy7o: Downloading webpage
# [youtube] cU0JrSAyy7o: Downloading android player API JSON
# [info] cU0JrSAyy7o: Downloading 1 format(s): 315+251
# [dashsegments] Total fragments: 62
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] IVE(아이브) 'I AM' (4K).f315.webm
# [download] 100% of  618.43MiB in 00:00:41 at 14.99MiB/s
# [dashsegments] Total fragments: 1
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] IVE(아이브) 'I AM' (4K).f251.webm
# [download] 100% of    3.33MiB in 00:00:00 at 13.85MiB/s
# [Merger] Merging formats into "downloaded_videos\choom\[BE ORIGINAL] IVE(아이브) 'I AM' (4K).webm"
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] IVE(아이브) 'I AM' (4K).f251.webm (pass -k to keep)
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] IVE(아이브) 'I AM' (4K).f315.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ql-q-biGUlU
# [youtube] ql-q-biGUlU: Downloading webpage
# [youtube] ql-q-biGUlU: Downloading android player API JSON
# [info] ql-q-biGUlU: Downloading 1 format(s): 315+251
# [dashsegments] Total fragments: 57
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] (G)I-DLE ((여자)아이들) 'TOMBOY' (4K).f315.webm
# [download] 100% of  569.14MiB in 00:00:37 at 15.22MiB/s
# [dashsegments] Total fragments: 1
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] (G)I-DLE ((여자)아이들) 'TOMBOY' (4K).f251.webm
# [download] 100% of    2.21MiB in 00:00:00 at 8.55MiB/s
# [Merger] Merging formats into "downloaded_videos\choom\[BE ORIGINAL] (G)I-DLE ((여자)아이들) 'TOMBOY' (4K).webm"
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] (G)I-DLE ((여자)아이들) 'TOMBOY' (4K).f315.webm (pass -k to keep)
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] (G)I-DLE ((여자)아이들) 'TOMBOY' (4K).f251.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Vp9I_m6znMM
# [youtube] Vp9I_m6znMM: Downloading webpage
# [youtube] Vp9I_m6znMM: Downloading android player API JSON
# [info] Vp9I_m6znMM: Downloading 1 format(s): 315+251
# [dashsegments] Total fragments: 61
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] ITZY(있지) 'WANNABE' (4K).f315.webm
# [download] 100% of  606.77MiB in 00:00:41 at 14.56MiB/s
# [dashsegments] Total fragments: 1
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] ITZY(있지) 'WANNABE' (4K).f251.webm
# [download] 100% of    3.07MiB in 00:00:00 at 10.58MiB/s
# [Merger] Merging formats into "downloaded_videos\choom\[BE ORIGINAL] ITZY(있지) 'WANNABE' (4K).webm"
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] ITZY(있지) 'WANNABE' (4K).f251.webm (pass -k to keep)
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] ITZY(있지) 'WANNABE' (4K).f315.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fXSXUKXuqu8
# [youtube] fXSXUKXuqu8: Downloading webpage
# [youtube] fXSXUKXuqu8: Downloading android player API JSON
# [info] fXSXUKXuqu8: Downloading 1 format(s): 315+251
# [dashsegments] Total fragments: 61
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] IZ＊ONE '환상동화(Secret Story of the Swan)' (4K).f315.webm
# [download] 100% of  607.08MiB in 00:00:34 at 17.55MiB/s
# [dashsegments] Total fragments: 1
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] IZ＊ONE '환상동화(Secret Story of the Swan)' (4K).f251.webm
# [download] 100% of    3.05MiB in 00:00:00 at 10.69MiB/s
# [Merger] Merging formats into "downloaded_videos\choom\[BE ORIGINAL] IZ＊ONE '환상동화(Secret Story of the Swan)' (4K).webm"
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] IZ＊ONE '환상동화(Secret Story of the Swan)' (4K).f251.webm (pass -k to keep)
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] IZ＊ONE '환상동화(Secret Story of the Swan)' (4K).f315.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=qORaYudQ7Zc
# [youtube] qORaYudQ7Zc: Downloading webpage
# [youtube] qORaYudQ7Zc: Downloading android player API JSON
# [info] qORaYudQ7Zc: Downloading 1 format(s): 315+251
# [dashsegments] Total fragments: 64
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] LE SSERAFIM(르세라핌) 'ANTIFRAGILE' (4K).f315.webm
# [download] 100% of  630.79MiB in 00:00:39 at 15.78MiB/s
# [dashsegments] Total fragments: 1
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] LE SSERAFIM(르세라핌) 'ANTIFRAGILE' (4K).f251.webm
# [download] 100% of    3.36MiB in 00:00:00 at 8.03MiB/s
# [Merger] Merging formats into "downloaded_videos\choom\[BE ORIGINAL] LE SSERAFIM(르세라핌) 'ANTIFRAGILE' (4K).webm"
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] LE SSERAFIM(르세라핌) 'ANTIFRAGILE' (4K).f315.webm (pass -k to keep)
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] LE SSERAFIM(르세라핌) 'ANTIFRAGILE' (4K).f251.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Igo8pUqvFMc
# [youtube] Igo8pUqvFMc: Downloading webpage
# [youtube] Igo8pUqvFMc: Downloading android player API JSON
# [info] Igo8pUqvFMc: Downloading 1 format(s): 315+251
# [dashsegments] Total fragments: 55
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] NAYEON(나연) 'POP!' (4K).f315.webm
# [download] 100% of  540.07MiB in 00:00:31 at 17.08MiB/s
# [dashsegments] Total fragments: 1
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] NAYEON(나연) 'POP!' (4K).f251.webm
# [download] 100% of    2.71MiB in 00:00:00 at 11.68MiB/s
# [Merger] Merging formats into "downloaded_videos\choom\[BE ORIGINAL] NAYEON(나연) 'POP!' (4K).webm"
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] NAYEON(나연) 'POP!' (4K).f315.webm (pass -k to keep)
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] NAYEON(나연) 'POP!' (4K).f251.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vWAC8Wkt9ok
# [youtube] vWAC8Wkt9ok: Downloading webpage
# [youtube] vWAC8Wkt9ok: Downloading android player API JSON
# [info] vWAC8Wkt9ok: Downloading 1 format(s): 315+251
# [dashsegments] Total fragments: 66
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] TWICE(트와이스) 'I CAN'T STOP ME' (4K).f315.webm
# [download] 100% of  657.97MiB in 00:00:38 at 17.15MiB/s
# [dashsegments] Total fragments: 1
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] TWICE(트와이스) 'I CAN'T STOP ME' (4K).f251.webm
# [download] 100% of    3.26MiB in 00:00:00 at 13.86MiB/s
# [Merger] Merging formats into "downloaded_videos\choom\[BE ORIGINAL] TWICE(트와이스) 'I CAN'T STOP ME' (4K).webm"
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] TWICE(트와이스) 'I CAN'T STOP ME' (4K).f315.webm (pass -k to keep)
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] TWICE(트와이스) 'I CAN'T STOP ME' (4K).f251.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LiNxfFkymTk
# [youtube] LiNxfFkymTk: Downloading webpage
# [youtube] LiNxfFkymTk: Downloading android player API JSON
# [info] LiNxfFkymTk: Downloading 1 format(s): 315+251
# [dashsegments] Total fragments: 58
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] LE SSERAFIM(르세라핌) 'FEARLESS' (4K).f315.webm
# [download] 100% of  577.69MiB in 00:00:36 at 15.91MiB/s
# [dashsegments] Total fragments: 1
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] LE SSERAFIM(르세라핌) 'FEARLESS' (4K).f251.webm
# [download] 100% of    2.92MiB in 00:00:00 at 11.22MiB/s
# [Merger] Merging formats into "downloaded_videos\choom\[BE ORIGINAL] LE SSERAFIM(르세라핌) 'FEARLESS' (4K).webm"
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] LE SSERAFIM(르세라핌) 'FEARLESS' (4K).f251.webm (pass -k to keep)
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] LE SSERAFIM(르세라핌) 'FEARLESS' (4K).f315.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v
iB/s
# [dashsegments] Total fragments: 1
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] EVERGLOW(에버글로우) 'DUN DUN' (4K).f251.webm
# [download] 100% of    3.11MiB in 00:00:00 at 11.23MiB/s
# [Merger] Merging formats into "downloaded_videos\choom\[BE ORIGINAL] EVERGLOW(에버글로우) 'DUN DUN' (4K).webm"
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] EVERGLOW(에버글로우) 'DUN DUN' (4K).f251.webm (pass -k to keep)
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] EVERGLOW(에버글로우) 'DUN DUN' (4K).f315.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=r7ZZCKmX2OI
# [youtube] r7ZZCKmX2OI: Downloading webpage
# [youtube] r7ZZCKmX2OI: Downloading android player API JSON
# [info] r7ZZCKmX2OI: Downloading 1 format(s): 315+251
# [dashsegments] Total fragments: 57
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] ITZY(있지) '마.피.아. In the morning' (4K).f315.webm
# [download] 100% of  565.62MiB in 00:00:31 at 17.80MiB/s
# [dashsegments] Total fragments: 1
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] ITZY(있지) '마.피.아. In the morning' (4K).f251.webm
# [download] 100% of    2.81MiB in 00:00:00 at 9.69MiB/s
# [Merger] Merging formats into "downloaded_videos\choom\[BE ORIGINAL] ITZY(있지) '마.피.아. In the morning' (4K).webm"
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] ITZY(있지) '마.피.아. In the morning' (4K).f315.webm (pass -k to keep)
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] ITZY(있지) '마.피.아. In the morning' (4K).f251.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=gR4OVNHBEVw
# [youtube] gR4OVNHBEVw: Downloading webpage
# [youtube] gR4OVNHBEVw: Downloading android player API JSON
# [info] gR4OVNHBEVw: Downloading 1 format(s): 315+251
# [dashsegments] Total fragments: 63
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] GFRIEND(여자친구) 'MAGO' (4K).f315.webm
# [download] 100% of  627.96MiB in 00:00:39 at 15.91MiB/s
# [dashsegments] Total fragments: 1
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] GFRIEND(여자친구) 'MAGO' (4K).f251.webm
# [download] 100% of    3.19MiB in 00:00:00 at 10.50MiB/s
# [Merger] Merging formats into "downloaded_videos\choom\[BE ORIGINAL] GFRIEND(여자친구) 'MAGO' (4K).webm"
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] GFRIEND(여자친구) 'MAGO' (4K).f251.webm (pass -k to keep)
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] GFRIEND(여자친구) 'MAGO' (4K).f315.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=lSqWEhrSZAM
# [youtube] lSqWEhrSZAM: Downloading webpage
# [youtube] lSqWEhrSZAM: Downloading android player API JSON
# [info] lSqWEhrSZAM: Downloading 1 format(s): 315+251
# [dashsegments] Total fragments: 55
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] NMIXX(엔믹스) '占 (TANK)' (4K).f315.webm
# [download] 100% of  540.12MiB in 00:00:32 at 16.78MiB/s
# [dashsegments] Total fragments: 1
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] NMIXX(엔믹스) '占 (TANK)' (4K).f251.webm
# [download] 100% of    2.76MiB in 00:00:00 at 9.22MiB/s
# [Merger] Merging formats into "downloaded_videos\choom\[BE ORIGINAL] NMIXX(엔믹스) '占 (TANK)' (4K).webm"
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] NMIXX(엔믹스) '占 (TANK)' (4K).f315.webm (pass -k to keep)
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] NMIXX(엔믹스) '占 (TANK)' (4K).f251.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zCkTa6hy4dY
# [youtube] zCkTa6hy4dY: Downloading webpage
# [youtube] zCkTa6hy4dY: Downloading android player API JSON
# [info] zCkTa6hy4dY: Downloading 1 format(s): 315+251
# [dashsegments] Total fragments: 66
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] Kep1er(케플러) 'Up!' (4K).f315.webm
# [download] 100% of  650.23MiB in 00:00:38 at 16.96MiB/s
# [dashsegments] Total fragments: 1
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] Kep1er(케플러) 'Up!' (4K).f251.webm
# [download] 100% of    3.43MiB in 00:00:00 at 8.66MiB/s
# [Merger] Merging formats into "downloaded_videos\choom\[BE ORIGINAL] Kep1er(케플러) 'Up!' (4K).webm"
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] Kep1er(케플러) 'Up!' (4K).f251.webm (pass -k to keep)
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] Kep1er(케플러) 'Up!' (4K).f315.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6fkcQGNr-g0
# [youtube] 6fkcQGNr-g0: Downloading webpage
# [youtube] 6fkcQGNr-g0: Downloading android player API JSON
# [info] 6fkcQGNr-g0: Downloading 1 format(s): 315+251
# [dashsegments] Total fragments: 66
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] STAYC(스테이씨) 'Teddy Bear' (4K).f315.webm
# [download] 100% of  659.04MiB in 00:00:39 at 16.49MiB/s
# [dashsegments] Total fragments: 1
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] STAYC(스테이씨) 'Teddy Bear' (4K).f251.webm
# [download] 100% of    3.37MiB in 00:00:00 at 11.17MiB/s
# [Merger] Merging formats into "downloaded_videos\choom\[BE ORIGINAL] STAYC(스테이씨) 'Teddy Bear' (4K).webm"
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] STAYC(스테이씨) 'Teddy Bear' (4K).f315.webm (pass -k to keep)
# Deleting original file downloaded_videos\choom\[BE ORIGINAL] STAYC(스테이씨) 'Teddy Bear' (4K).f251.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rnVN6UZl6bU
# [youtube] rnVN6UZl6bU: Downloading webpage
# [youtube] rnVN6UZl6bU: Downloading android player API JSON
# [info] rnVN6UZl6bU: Downloading 1 format(s): 315+251
# [dashsegments] Total fragments: 68
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] EVERGLOW(에버글로우) 'LA DI DA' (4K).f315.webm
# [download] 100% of  672.15MiB in 00:00:41 at 16.11MiB/s
# [dashsegments] Total fragments: 1
# [download] Destination: downloaded_videos\choom\[BE ORIGINAL] EVERGLOW(에버글로우) 
loaded_videos\choom\[BE ORIGINAL] EVERGLOW(에버글로우) 'DUN DUN' (4K).webm has already been downloaded
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rnVN6UZl6bU
# [youtube] rnVN6UZl6bU: Downloading webpage
# [youtube] rnVN6UZl6bU: Downloading android player API JSON
# [info] rnVN6UZl6bU: Downloading 1 format(s): 315+251
# [download] downloaded_videos\choom\[BE ORIGINAL] EVERGLOW(에버글로우) 'LA DI DA' (4K).webm has already been downloaded

# %% [markdown]
# ## 2. File Sanitization
#
# To ensure smooth processing and to avoid any interference from weird symbols, we sanitize the file names in this section.

# %%
import os
import re

def is_valid_char(c):
    return c.isalnum() and c.isascii() or c == '.'

def sanitize_filename(filename):
    return ''.join([c if is_valid_char(c) else '' for c in filename])

input_dir = "downloaded_videos"

for filename in os.listdir(input_dir):
    if filename.endswith(".webm"):
        old_path = os.path.join(input_dir, filename)
        new_filename = sanitize_filename(filename)
        new_path = os.path.join(input_dir, new_filename)
        os.rename(old_path, new_path)
        print(f"Renamed {old_path} to {new_path}")
# Out:
# Renamed downloaded_videos/choom\BEORIGINALaespaGirlsK.webm to downloaded_videos/choom\BEORIGINALaespaGirlsK.webm
# Renamed downloaded_videos/choom\BEORIGINALaespaNextLevelK.webm to downloaded_videos/choom\BEORIGINALaespaNextLevelK.webm
# Renamed downloaded_videos/choom\BEORIGINALBilllieRINGmaBellK.webm to downloaded_videos/choom\BEORIGINALBilllieRINGmaBellK.webm
# Renamed downloaded_videos/choom\BEORIGINALEVERGLOWDUNDUNK.webm to downloaded_videos/choom\BEORIGINALEVERGLOWDUNDUNK.webm
# Renamed downloaded_videos/choom\BEORIGINALEVERGLOWLADIDAK.webm to downloaded_videos/choom\BEORIGINALEVERGLOWLADIDAK.webm
# Renamed downloaded_videos/choom\BEORIGINALGFRIENDMAGOK.webm to downloaded_videos/choom\BEORIGINALGFRIENDMAGOK.webm
# Renamed downloaded_videos/choom\BEORIGINALGIDLEOhmygodK.webm to downloaded_videos/choom\BEORIGINALGIDLEOhmygodK.webm
# Renamed downloaded_videos/choom\BEORIGINALGIDLETOMBOYK.webm to downloaded_videos/choom\BEORIGINALGIDLETOMBOYK.webm
# Renamed downloaded_videos/choom\BEORIGINALITZY...InthemorningK.webm to downloaded_videos/choom\BEORIGINALITZY...InthemorningK.webm
# Renamed downloaded_videos/choom\BEORIGINALITZYLOCOK.webm to downloaded_videos/choom\BEORIGINALITZYLOCOK.webm
# Renamed downloaded_videos/choom\BEORIGINALITZYNotShyK.webm to downloaded_videos/choom\BEORIGINALITZYNotShyK.webm
# Renamed downloaded_videos/choom\BEORIGINALITZYSNEAKERSK.webm to downloaded_videos/choom\BEORIGINALITZYSNEAKERSK.webm
# Renamed downloaded_videos/choom\BEORIGINALITZYWANNABEK.webm to downloaded_videos/choom\BEORIGINALITZYWANNABEK.webm
# Renamed downloaded_videos/choom\BEORIGINALIVEIAMK.webm to downloaded_videos/choom\BEORIGINALIVEIAMK.webm
# Renamed downloaded_videos/choom\BEORIGINALIZONESecretStoryoftheSwanK.webm to downloaded_videos/choom\BEORIGINALIZONESecretStoryoftheSwanK.webm
# Renamed downloaded_videos/choom\BEORIGINALKeperGiddyK.webm to downloaded_videos/choom\BEORIGINALKeperGiddyK.webm
# Renamed downloaded_videos/choom\BEORIGINALKeperUpK.webm to downloaded_videos/choom\BEORIGINALKeperUpK.webm
# Renamed downloaded_videos/choom\BEORIGINALKeperWADADAK.webm to downloaded_videos/choom\BEORIGINALKeperWADADAK.webm
# Renamed downloaded_videos/choom\BEORIGINALLESSERAFIMANTIFRAGILEK.webm to downloaded_videos/choom\BEORIGINALLESSERAFIMANTIFRAGILEK.webm
# Renamed downloaded_videos/choom\BEORIGINALLESSERAFIMFEARLESSK.webm to downloaded_videos/choom\BEORIGINALLESSERAFIMFEARLESSK.webm
# Renamed downloaded_videos/choom\BEORIGINALLIGHTSUMVIVACEK.webm to downloaded_videos/choom\BEORIGINALLIGHTSUMVIVACEK.webm
# Renamed downloaded_videos/choom\BEORIGINALNAYEONPOPK.webm to downloaded_videos/choom\BEORIGINALNAYEONPOPK.webm
# Renamed downloaded_videos/choom\BEORIGINALNMIXXDICEK.webm to downloaded_videos/choom\BEORIGINALNMIXXDICEK.webm
# Renamed downloaded_videos/choom\BEORIGINALNMIXXO.OK.webm to downloaded_videos/choom\BEORIGINALNMIXXO.OK.webm
# Renamed downloaded_videos/choom\BEORIGINALNMIXXTANKK.webm to downloaded_videos/choom\BEORIGINALNMIXXTANKK.webm
# Renamed downloaded_videos/choom\BEORIGINALOHMYGIRLNonstopK.webm to downloaded_videos/choom\BEORIGINALOHMYGIRLNonstopK.webm
# Renamed downloaded_videos/choom\BEORIGINALSOMIDUMBDUMBK.webm to downloaded_videos/choom\BEORIGINALSOMIDUMBDUMBK.webm
# Renamed downloaded_videos/choom\BEORIGINALSTAYCTeddyBearK.webm to downloaded_videos/choom\BEORIGINALSTAYCTeddyBearK.webm
# Renamed downloaded_videos/choom\BEORIGINALTWICEAlcoholFreeK.webm to downloaded_videos/choom\BEORIGINALTWICEAlcoholFreeK.webm
# Renamed downloaded_videos/choom\BEORIGINALTWICEICANTSTOPMEK.webm to downloaded_videos/choom\BEORIGINALTWICEICANTSTOPMEK.webm

# %% [markdown]
# ## 3. Face Detection and Upscaling
#
# This section of the code navigates through each directory in the `downloaded-videos` folder. For each `.WEBM` file, it creates a new directory storing the detected faces in the video.
#
# ### Requirements:
#
# To run this code, you need two models in your working directory:
# - `shape_predictor_5_face_landmarks.dat`: This model enables the face detection capability.
# - `FSRCNN_x2.pb`: This model enables the 2x upscaling of detected faces, allowing for faster processing and good quality images.
#
# ### Variables for Modification:
#
# Here are a few variables that you may want to modify:
#
# - `every_n_frames`: Originally set to `1`, this means that face detection will be run on every frame of the video.
# - `max_workers`: Originally set to `4` as my CPU has 4 cores. This code can run in parallel, so increase or decrease this variable according to your system's capabilities.
# - `padding_factor`: Originally set to `1.3` which is a reasonable value, adjust this to modify the size of the captured image. Decrease to zoom into the face more, increase to capture a larger facial image outside of the face.

# %%
import cv2
import dlib
import math
import numpy as np
from pathlib import Path
import random
import string
from concurrent.futures import ThreadPoolExecutor, as_completed
import os
from tqdm import tqdm


def filter_images(image):
    detector = dlib.get_frontal_face_detector()
    if image is not None and image.shape[0] > 511 and image.shape[1] > 511:
        gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        faces = detector(gray_image, upsample_num_times=0)
        return len(faces) > 0, gray_image
    return False, None


def face_score(gray_image):
    detector = dlib.get_frontal_face_detector()
    faces, scores, _ = detector.run(gray_image, upsample_num_times=0)
    return faces, scores


def find_eyes(image, face):
    predictor = dlib.shape_predictor('shape_predictor_5_face_landmarks.dat')

    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    shape = predictor(gray, face)
    left_eye = ((shape.part(3).x + shape.part(2).x) // 2, (shape.part(3).y + shape.part(2).y) // 2)
    right_eye = ((shape.part(1).x + shape.part(0).x) // 2, (shape.part(1).y + shape.part(0).y) // 2)
    return left_eye, right_eye


def upscale_image_fsrcnn(image, model_path):
    sr = cv2.dnn_superres.DnnSuperResImpl_create()
    sr.readModel(model_path)
    sr.setModel("fsrcnn", 2)
    upscaled_image = sr.upsample(image)
    return upscaled_image


def center_eyes(img, model_path="FSRCNN_x2.pb"):
    detector = dlib.get_frontal_face_detector()
    
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = detector(gray, upsample_num_times=0)
    if len(faces) == 0:
        return None
    face = faces[0]
    left_eye, right_eye = find_eyes(img, face)
    # rest of the function remains unchanged

    center = ((left_eye[0] + right_eye[0]) // 2, (left_eye[1] + right_eye[1]) // 2)
    dy = right_eye[1] - left_eye[1]
    dx = right_eye[0] - left_eye[0]
    angle = math.degrees(math.atan2(dy, dx))
    height, width, _ = img.shape
    eye_distance = int(math.sqrt((right_eye[0] - left_eye[0]) ** 2 + (right_eye[1] - left_eye[1]) ** 2))


    M_rotate = cv2.getRotationMatrix2D(center, angle, 1)
    rotated_img = cv2.warpAffine(img, M_rotate, (width, height))

    rotated_center = tuple(map(int, M_rotate.dot(np.array([center[0], center[1], 1]))))

    dx_translation = width // 2 - rotated_center[0]
    dy_translation = height // 2 - rotated_center[1]
    M_translate = np.float32([[1, 0, dx_translation], [0, 1, dy_translation]])
    translated_img = cv2.warpAffine(rotated_img, M_translate, (width, height), flags=cv2.INTER_LANCZOS4)
    reference_eye_distance = 260
    scaling_factor = reference_eye_distance / eye_distance

    scaled_height = int(height * scaling_factor)
    scaled_width = int(width * scaling_factor)
    
    if scaling_factor > 1:
        translated_img = upscale_image_fsrcnn(translated_img, model_path)

    scaled_img = cv2.resize(translated_img, (scaled_width, scaled_height), interpolation=cv2.INTER_LANCZOS4)  # Use cv2.INTER_LANCZOS4 interpolation


    center_y = scaled_height // 2
    center_x = scaled_width // 2
    cropped_img = scaled_img[center_y - 512:center_y + 512, center_x - 512:center_x + 512]
    return cropped_img



def crop_face(image, face):
    left_eye, right_eye = find_eyes(image, face)
    return center_eyes(image, left_eye, right_eye)


def convert_to_png(image, faces, output_path):
    for face in faces:
        cropped_face = crop_face(image, face)
        if cropped_face.shape[0] < 512 or cropped_face.shape[1] < 512:
            continue
        face_area = (face.bottom() - face.top()) * (face.right() - face.left())
        random_suffix = ''.join(random.choices(string.ascii_letters, k=4))
        file_name = f'{face_area}_{random_suffix}.png'
        output_image_path = output_path / file_name
        cv2.imwrite(str(output_image_path), cropped_face)


def process_single_image(input_image_path, output_dir):
    detector = dlib.get_frontal_face_detector()

    image = cv2.imread(str(input_image_path))
    filtered, gray_image = filter_images(image)
    if filtered:
        relative_path = input_image_path.parent.relative_to(input_dir)
        output_subdir = output_dir / relative_path
        output_subdir.mkdir(parents=True, exist_ok=True)
        faces = detector(gray_image, upsample_num_times=0)
        convert_to_png(image, faces, output_subdir)

def process_video(video_path, output_path, every_n_frames=1,
                  score_threshold=-2, model_path="FSRCNN_x2.pb", padding_factor=1.3):
    detector = dlib.get_frontal_face_detector()
    cap = cv2.VideoCapture(str(video_path))
    if not cap.isOpened():
        print("Error opening the video file.")
        return
    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        if frame_count % every_n_frames == 0:
            gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            faces, scores, _ = detector.run(gray_frame, upsample_num_times=0)
            if len(faces) > 0:
                for face in faces:
                    x1, y1, x2, y2 = face.left(), face.top(), face.right(), face.bottom()
                    width, height = x2 - x1, y2 - y1

                    if width > 512 and height > 512:  # Updated condition
                        pad_x = int(width * padding_factor)
                        pad_y = int(height * padding_factor)
                        x1 = max(0, x1 - pad_x)
                        y1 = max(0, y1 - pad_y)
                        x2 = min(frame.shape[1], x2 + pad_x)
                        y2 = min(frame.shape[0], y2 + pad_y)
                        face_img = frame[y1:y2, x1:x2]

                        centered_face_img = center_eyes(face_img, model_path)
                        random_suffix = ''.join(random.choices(string.ascii_letters, k=4))
                        face_area = (y2 - y1) * (x2 - x1)
                        face_output_path = output_path / f"{face_area}_frame{frame_count}_{random_suffix}.png"
                        if centered_face_img is not None:
                            cv2.imwrite(str(face_output_path), centered_face_img)


        frame_count += 1
    cap.release()



def process_videos_in_parallel(input_dir, output_dir, max_workers=2):
    input_dir = Path(input_dir)
    output_dir = Path(output_dir)

    video_paths = list(input_dir.glob("**/*.webm"))
    video_paths.extend(input_dir.glob("**/*.mp4"))
    video_paths.extend(input_dir.glob("**/*.avi"))
    video_paths.extend(input_dir.glob("**/*.mkv"))

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {}
        for video_path in video_paths:
            relative_path = video_path.parent.relative_to(input_dir)
            output_subdir = output_dir / relative_path
            video_name = video_path.stem
            output_path = output_subdir / video_name

            # Create output directories if they don't exist
            output_path.mkdir(parents=True, exist_ok=True)

            future = executor.submit(process_video, video_path, output_path)
            futures[future] = video_path

        for future in tqdm(as_completed(futures), total=len(futures), desc="Processing videos", unit="video"):
            video_path = futures[future]
            try:
                future.result()
            except Exception as e:
                print(f"Error processing video {video_path}: {e}")


input_dir = "downloaded_videos"
output_dir = "kpop-faces"
process_videos_in_parallel(input_dir, output_dir, max_workers=2)
# Out:
# Processing videos:  20%|██        | 6/30 [20:40:59<49:31:11, 7427.99s/video]
